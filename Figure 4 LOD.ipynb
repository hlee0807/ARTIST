# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.gridspec import GridSpec
from scipy.integrate import odeint
from scipy.optimize import curve_fit
import math
from scipy.stats import t

# Plot settings
lw = 2
fs = 20


# Load the data
data = pd.read_excel('Figure4_Steadystateplots.xlsx')
data_plot = data.loc[:, 'IFN_RNH1':'TNF_RNH_Avg+Stdev']
protein = data['Conc']

# Create the subplots with gridspec
fig = plt.figure(facecolor='w')
gs = GridSpec(1, 2, width_ratios=[0.15, 0.85])  # Adjust the width ratios as needed

ax = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1], sharey=ax)

# Plot data on ax
ax.plot(protein, data_plot['IFN_RNH_Avg'], marker='o', color=(0, 0, 1),
        markerfacecolor=(0, 0, 1), linewidth=1, markersize=0)
ax.plot(protein, data_plot['IFN_RNH1'], marker='o', color=(0, 0, 1),
        markerfacecolor=(0, 0, 1), linewidth=0, markersize=7, label='Experiment')
ax.plot(protein, data_plot['IFN_RNH2'], marker='o', color=(0, 0, 1),
        markerfacecolor=(0, 0, 1), linewidth=0, markersize=7)

# Plot data on ax2
ax2.plot(protein, data_plot['IFN_RNH_Avg'], marker='o', color=(0, 0, 1),
        markerfacecolor=(0, 0, 1), linewidth=1, markersize=0)
ax2.plot(protein, data_plot['IFN_RNH1'], marker='o', color=(0, 0, 1),
        markerfacecolor=(0, 0, 1), linewidth=0, markersize=7, label='Experiment')
ax2.plot(protein, data_plot['IFN_RNH2'], marker='o', color=(0, 0, 1),
        markerfacecolor=(0, 0, 1), linewidth=0, markersize=7)

ax.fill_between(protein, data_plot['IFN_RNH_Avg-Stdev'],  data_plot['IFN_RNH_Avg+Stdev'], color=(0,0,1), alpha=0.2, linewidth = 0, interpolate=True)
ax2.fill_between(protein, data_plot['IFN_RNH_Avg-Stdev'],  data_plot['IFN_RNH_Avg+Stdev'], color=(0,0,1), alpha=0.2, linewidth = 0, interpolate=True)

# Modified sigmoidal function (4PL model) with fixed A and B

L = np.array([0.000000000005, 5, 10, 100, 1000])

# A and B are determined from empirical results
A = 2.281555002 # min Reacted reporter concentration
B = 53.0270479 # max Reacted reporter concentration
def sigmoid(x, C, D):
    # C = fitted value - EC50 value
    # D = fitted value - slope of the point of inflection
    return A + (B - A) / (1 + (x / C)**D)

# Initial guesses for parameters [C, D]
initial_guesses = [1, 1]

# Perform sigmoidal regression (fit the 4PL model with fixed A and B)
popt, pcov = curve_fit(sigmoid, L, data_plot['IFN_RNH_Avg'], p0=initial_guesses, bounds=(0, np.inf))
C_fit, D_fit = popt

# Generate fitted curve
L_fit = np.logspace(-8, 4, 1000)
Reporter_fit = sigmoid(L_fit, *popt)

# Standard errors of the parameters
perr = np.sqrt(np.diag(pcov))

# Confidence intervals
C_fit_ci = 1.96 * perr[0]
D_fit_ci = 1.96 * perr[1]

# Calculate LOD
y0 = 53.0270479
stdev0 = 1.954322076
y_LOD = y0 - 3 * stdev0

# Inverse function to find the corresponding concentration for y_LOD
def find_LOD(y_LOD, A, B, C, D):
    logLOD = np.log(C) - (1/-D)*np.log(((B - y_LOD) / (y_LOD - A)))
    return 2.71828183**logLOD

LOD = find_LOD(y_LOD, A, B, C_fit, D_fit)

# Partial derivative of LOD with respect to C
dLOD_dC = ((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)
# Partial derivative of LOD with respect to D
dLOD_dD = C_fit * (((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)) * (-np.log((B - y_LOD) / (y_LOD - A)) / D_fit**2)

# Calculate LOD error using error propagation formula
LOD_error = np.sqrt((C_fit_ci * dLOD_dC)**2 + (D_fit_ci * dLOD_dD)**2)


# Plot the fitted curve
ax.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')
ax2.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')

# Set x-axis limits and scales
ax.set_xlim(0.000000005, 0.00000005)
ax2.set_xlim(1, 10000)
ax.set_xscale('log')
ax2.set_xscale('log')
plt.ylim(-7.5, 75)

# Hide spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Set font size for y-axis label
ax.set_ylabel('[Reacted Reporter] (nM)', fontsize=fs)
ax2.set_ylabel('[Reacted Reporter] (nM)', fontsize=0)
ax.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax.yaxis.set_tick_params(which='both', size=3, width=1, direction='in', right='on')
ax2.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax2.yaxis.set_tick_params(which='both', size=0, width=0, direction='in', right='on')

# Mark the LOD on the plot
ax.axhline(y=y_LOD, color='black', linestyle='--')
ax.axvline(x=LOD, color='black', linestyle='--')
ax2.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=LOD, color='black', linestyle='--')

# Set font size for tick labels
ax.tick_params(axis='both', which='major', labelsize=fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)

# Add more ticks on the x-axis for ax2
ax2.set_xticks([10**n for n in range(1, 5)])  # Ticks at 10, 100, 1000, 10000
# ax2.get_xaxis().set_major_formatter(plt.ScalarFormatter())  # Format ticks as integers

# Add the diagonal lines for broken axis effect
d = .015  # How big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # Switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# Add a single, centered x-axis label
fig.text(0.5, 0.001, '[IFN-γ] (nM)', ha='center', fontsize=fs)


plt.legend(fontsize=fs-6)

# Show plot
# plt.savefig('060624_IFNanalog_sigmoidfitting.svg')
plt.show()

# Print the fitted parameters
print(f"Fixed parameters: A = {A}, B = {B}")
print(f"Fitted parameter C: {C_fit:.2f} ± {C_fit_ci:.2f}")
print(f"Fitted parameter D: {D_fit:.2f} ± {D_fit_ci:.2f}")
print(f"LOD: {LOD:.2f} ± {LOD_error:.2f}")
# Out:
# /Users/heonjoonlee/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Fixed parameters: A = 2.281555002, B = 53.0270479
# Fitted parameter C: 5.83 ± 0.98
# Fitted parameter D: 1.43 ± 0.60
# LOD: 1.41 ± 0.87

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.gridspec import GridSpec
from scipy.integrate import odeint
from scipy.optimize import curve_fit
import math
from scipy.stats import t

# Plot settings
lw = 2
fs = 20


# Load the data
data = pd.read_excel('Figure4_Steadystateplots.xlsx')
data_plot = data.loc[:, 'IFN_RNH1':'TNF_RNH_Avg+Stdev']
protein = data['Conc']

# Create the subplots with gridspec
fig = plt.figure(facecolor='w')
gs = GridSpec(1, 2, width_ratios=[0.15, 0.85])  # Adjust the width ratios as needed

ax = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1], sharey=ax)

# Plot data on ax
ax.plot(protein, data_plot['Thr_RNH_Avg'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0, 1), linewidth=1, markersize=0)
ax.plot(protein, data_plot['Thr_RNH1'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7, label='Experiment')
ax.plot(protein, data_plot['Thr_RNH2'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7)

# Plot data on ax2
ax2.plot(protein, data_plot['Thr_RNH_Avg'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0, 1), linewidth=1, markersize=0)
ax2.plot(protein, data_plot['Thr_RNH1'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7, label='Experiment')
ax2.plot(protein, data_plot['Thr_RNH2'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7)

ax.fill_between(protein, data_plot['Thr_RNH_Avg-Stdev'],  data_plot['Thr_RNH_Avg+Stdev'], color=(0,0.6,0), alpha=0.2, linewidth = 0, interpolate=True)
ax2.fill_between(protein, data_plot['Thr_RNH_Avg-Stdev'],  data_plot['Thr_RNH_Avg+Stdev'], color=(0,0.6,0), alpha=0.2, linewidth = 0, interpolate=True)

# Modified sigmoidal function (4PL model) with fixed A and B

L = np.array([0.000000000005, 5, 10, 100, 1000])

# A and B are determined from empirical results
A = 0.597756589 # min Reacted reporter concentration
B = 35.3064685 # max Reacted reporter concentration
def sigmoid(x, C, D):
    # C = fitted value - EC50 value
    # D = fitted value - slope of the point of inflection
    return A + (B - A) / (1 + (x / C)**D)

# Initial guesses for parameters [C, D]
initial_guesses = [1, 1]

# Perform sigmoidal regression (fit the 4PL model with fixed A and B)
popt, pcov = curve_fit(sigmoid, L, data_plot['Thr_RNH_Avg'], p0=initial_guesses, bounds=(0, np.inf))
C_fit, D_fit = popt

# Generate fitted curve
L_fit = np.logspace(-8, 4, 1000)
Reporter_fit = sigmoid(L_fit, *popt)

# Standard errors of the parameters
perr = np.sqrt(np.diag(pcov))

# Confidence intervals
C_fit_ci = 1.96 * perr[0]
D_fit_ci = 1.96 * perr[1]

# Calculate LOD
y0 = 35.3064685
stdev0 = 0.87377189
y_LOD = y0 - 3 * stdev0

# Inverse function to find the corresponding concentration for y_LOD
def find_LOD(y_LOD, A, B, C, D):
    logLOD = np.log(C) - (1/-D)*np.log(((B - y_LOD) / (y_LOD - A)))
    return 2.71828183**logLOD

LOD = find_LOD(y_LOD, A, B, C_fit, D_fit)

# Partial derivative of LOD with respect to C
dLOD_dC = ((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)
# Partial derivative of LOD with respect to D
dLOD_dD = C_fit * (((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)) * (-np.log((B - y_LOD) / (y_LOD - A)) / D_fit**2)

# Calculate LOD error using error propagation formula
LOD_error = np.sqrt((C_fit_ci * dLOD_dC)**2 + (D_fit_ci * dLOD_dD)**2)

# Plot the results

# Plot the fitted curve
ax.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')
ax2.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')

# Set x-axis limits and scales
ax.set_xlim(0.000000005, 0.00000005)
ax2.set_xlim(1, 10000)
ax.set_xscale('log')
ax2.set_xscale('log')
plt.ylim(-7.5, 75)

# Hide spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Set font size for y-axis label
ax.set_ylabel('[Reacted Reporter] (nM)', fontsize=fs)
ax2.set_ylabel('[Reacted Reporter] (nM)', fontsize=0)
ax.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax.yaxis.set_tick_params(which='both', size=3, width=1, direction='in', right='on')
ax2.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax2.yaxis.set_tick_params(which='both', size=0, width=0, direction='in', right='on')

# Mark the LOD on the plot
ax.axhline(y=y_LOD, color='black', linestyle='--')
ax.axvline(x=LOD, color='black', linestyle='--')
ax2.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=LOD, color='black', linestyle='--')



# Set font size for tick labels
ax.tick_params(axis='both', which='major', labelsize=fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)

# Add more ticks on the x-axis for ax2
ax2.set_xticks([10**n for n in range(1, 5)])  # Ticks at 10, 100, 1000, 10000
# ax2.get_xaxis().set_major_formatter(plt.ScalarFormatter())  # Format ticks as integers

# Add the diagonal lines for broken axis effect
d = .015  # How big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # Switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# Add a single, centered x-axis label
fig.text(0.5, 0.001, '[Thrombin] (nM)', ha='center', fontsize=fs)


plt.legend(fontsize=fs-6)

# Show plot
# plt.savefig('060624_Thranalog_sigmoidfitting.svg')
plt.show()

# Print the fitted parameters
print(f"Fixed parameters: A = {A}, B = {B}")
print(f"Fitted parameter C: {C_fit:.2f} ± {C_fit_ci:.2f}")
print(f"Fitted parameter D: {D_fit:.2f} ± {D_fit_ci:.2f}")
print(f"LOD: {LOD:.2f} ± {LOD_error:.2f}")
# Out:
# Fixed parameters: A = 0.597756589, B = 35.3064685
# Fitted parameter C: 8.74 ± 0.28
# Fitted parameter D: 1.54 ± 0.12
# LOD: 1.71 ± 0.23

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.gridspec import GridSpec
from scipy.integrate import odeint
from scipy.optimize import curve_fit
import math
from scipy.stats import t

# Plot settings
lw = 2
fs = 20


# Load the data
data = pd.read_excel('Figure4_Steadystateplots.xlsx')
data_plot = data.loc[:, 'IFN_RNH1':'TNF_RNH_Avg+Stdev']
protein = data['Conc']

# Create the subplots with gridspec
fig = plt.figure(facecolor='w')
gs = GridSpec(1, 2, width_ratios=[0.15, 0.85])  # Adjust the width ratios as needed

ax = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1], sharey=ax)

# Plot data on ax
ax.plot(protein, data_plot['IL6_RNH_Avg'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0, 0, 1), linewidth=1, markersize=0)
ax.plot(protein, data_plot['IL6_RNH1'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7, label='Experiment')
ax.plot(protein, data_plot['IL6_RNH2'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7)

# Plot data on ax2
ax2.plot(protein, data_plot['IL6_RNH_Avg'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0, 0, 1), linewidth=1, markersize=0)
ax2.plot(protein, data_plot['IL6_RNH1'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7, label='Experiment')
ax2.plot(protein, data_plot['IL6_RNH2'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7)

ax.fill_between(protein, data_plot['IL6_RNH_Avg-Stdev'],  data_plot['IL6_RNH_Avg+Stdev'], color=(0.5,0,0.5), alpha=0.2, linewidth = 0, interpolate=True)
ax2.fill_between(protein, data_plot['IL6_RNH_Avg-Stdev'],  data_plot['IL6_RNH_Avg+Stdev'], color=(0.5,0,0.5), alpha=0.2, linewidth = 0, interpolate=True)


# Modified sigmoidal function (4PL model) with fixed A and B

L = np.array([0.000000000005, 5, 10, 100, 1000])

# A and B are determined from empirical results
A = 4.598087585 # min Reacted reporter concentration
B = 47.7559626 # max Reacted reporter concentration
def sigmoid(x, C, D):
    # C = fitted value - EC50 value
    # D = fitted value - slope of the point of inflection
    return A + (B - A) / (1 + (x / C)**D)

# Initial guesses for parameters [C, D]
initial_guesses = [1, 1]

# Perform sigmoidal regression (fit the 4PL model with fixed A and B)
popt, pcov = curve_fit(sigmoid, L, data_plot['IL6_RNH_Avg'], p0=initial_guesses, bounds=(0, np.inf))
C_fit, D_fit = popt

# Generate fitted curve
L_fit = np.logspace(-8, 4, 1000)
Reporter_fit = sigmoid(L_fit, *popt)

# Standard errors of the parameters
perr = np.sqrt(np.diag(pcov))

# Confidence intervals
C_fit_ci = 1.96 * perr[0]
D_fit_ci = 1.96 * perr[1]

# Calculate LOD
y0 = 47.7559626
stdev0 = 3.43810774
y_LOD = y0 - 3 * stdev0

# Inverse function to find the corresponding concentration for y_LOD
def find_LOD(y_LOD, A, B, C, D):
    logLOD = np.log(C) - (1/-D)*np.log(((B - y_LOD) / (y_LOD - A)))
    return 2.71828183**logLOD

LOD = find_LOD(y_LOD, A, B, C_fit, D_fit)

# Partial derivative of LOD with respect to C
dLOD_dC = ((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)
# Partial derivative of LOD with respect to D
dLOD_dD = C_fit * (((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)) * (-np.log((B - y_LOD) / (y_LOD - A)) / D_fit**2)

# Calculate LOD error using error propagation formula
LOD_error = np.sqrt((C_fit_ci * dLOD_dC)**2 + (D_fit_ci * dLOD_dD)**2)



# Plot the fitted curve
ax.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')
ax2.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')

# Mark the LOD on the plot
ax.axhline(y=y_LOD, color='black', linestyle='--')
ax.axvline(x=LOD, color='black', linestyle='--')
ax2.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=LOD, color='black', linestyle='--')

# Set x-axis limits and scales
ax.set_xlim(0.000000005, 0.00000005)
ax2.set_xlim(1, 10000)
ax.set_xscale('log')
ax2.set_xscale('log')
plt.ylim(-7.5, 75)

# Hide spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Set font size for y-axis label
ax.set_ylabel('[Reacted Reporter] (nM)', fontsize=fs)
ax2.set_ylabel('[Reacted Reporter] (nM)', fontsize=0)
ax.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax.yaxis.set_tick_params(which='both', size=3, width=1, direction='in', right='on')
ax2.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax2.yaxis.set_tick_params(which='both', size=0, width=0, direction='in', right='on')

# plt.scatter(6.29,72.68620386, color = 'red')

# Set font size for tick labels
ax.tick_params(axis='both', which='major', labelsize=fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)

# Add more ticks on the x-axis for ax2
ax2.set_xticks([10**n for n in range(1, 5)])  # Ticks at 10, 100, 1000, 10000
# ax2.get_xaxis().set_major_formatter(plt.ScalarFormatter())  # Format ticks as integers

# Add the diagonal lines for broken axis effect
d = .015  # How big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # Switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# Add a single, centered x-axis label
fig.text(0.5, 0.001, '[IL-6] (nM)', ha='center', fontsize=fs)

plt.legend(fontsize=fs-6)

# Show plot
# plt.savefig('060624_IL6analog_sigmoidfitting.svg')
plt.show()

# Print the fitted parameters
print(f"Fixed parameters: A = {A}, B = {B}")
print(f"Fitted parameter C: {C_fit:.2f} ± {C_fit_ci:.2f}")
print(f"Fitted parameter D: {D_fit:.2f} ± {D_fit_ci:.2f}")
print(f"LOD: {LOD:.2f} ± {LOD_error:.2f}")
# Out:
# Fixed parameters: A = 4.598087585, B = 47.7559626
# Fitted parameter C: 6.53 ± 0.63
# Fitted parameter D: 0.77 ± 0.09
# LOD: 1.44 ± 0.28

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.gridspec import GridSpec
from scipy.integrate import odeint
from scipy.optimize import curve_fit
import math
from scipy.stats import t

# Plot settings
lw = 2
fs = 20


# Load the data
data = pd.read_excel('Figure4_Steadystateplots.xlsx')
data_plot = data.loc[:, 'IFN_RNH1':'TNF_RNH_Avg+Stdev']
protein = data['Conc']

# Create the subplots with gridspec
fig = plt.figure(facecolor='w')
gs = GridSpec(1, 2, width_ratios=[0.15, 0.85])  # Adjust the width ratios as needed

ax = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1], sharey=ax)

# Plot data on ax
ax.plot(protein, data_plot['TNF_RNH_Avg'], marker='o', color=(1, 0, 0),
        markerfacecolor=(0, 0, 1), linewidth=1, markersize=0)
ax.plot(protein, data_plot['TNF_RNH1'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7, label='Experiment')
ax.plot(protein, data_plot['TNF_RNH2'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7)

# Plot data on ax2
ax2.plot(protein, data_plot['TNF_RNH_Avg'], marker='o', color=(1, 0, 0),
        markerfacecolor=(0, 0, 1), linewidth=1, markersize=0)
ax2.plot(protein, data_plot['TNF_RNH1'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7, label='Experiment')
ax2.plot(protein, data_plot['TNF_RNH2'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7)

ax.fill_between(protein, data_plot['TNF_RNH_Avg-Stdev'],  data_plot['TNF_RNH_Avg+Stdev'], color=(1,0,0), alpha=0.2, linewidth = 0, interpolate=True)
ax2.fill_between(protein, data_plot['TNF_RNH_Avg-Stdev'],  data_plot['TNF_RNH_Avg+Stdev'], color=(1,0,0), alpha=0.2, linewidth = 0, interpolate=True)


# Modified sigmoidal function (4PL model) with fixed A and B

L = np.array([0.000000000005, 5, 10, 100, 1000])

# A and B are determined from empirical results
A = 4.869470937 # min Reacted reporter concentration
B = 51.10321879 # max Reacted reporter concentration
def sigmoid(x, C, D):
    # C = fitted value - EC50 value
    # D = fitted value - slope of the point of inflection
    return A + (B - A) / (1 + (x / C)**D)

# Initial guesses for parameters [C, D]
initial_guesses = [1, 1]

# Perform sigmoidal regression (fit the 4PL model with fixed A and B)
popt, pcov = curve_fit(sigmoid, L, data_plot['TNF_RNH_Avg'], p0=initial_guesses, bounds=(0, np.inf))
C_fit, D_fit = popt

# Generate fitted curve
L_fit = np.logspace(-8, 4, 1000)
Reporter_fit = sigmoid(L_fit, *popt)

# Standard errors of the parameters
perr = np.sqrt(np.diag(pcov))

# Confidence intervals
C_fit_ci = 1.96 * perr[0]
D_fit_ci = 1.96 * perr[1]

# Calculate LOD
y0 = 51.10321879
stdev0 = 2.335682966
y_LOD = y0 - 3 * stdev0

# Inverse function to find the corresponding concentration for y_LOD
def find_LOD(y_LOD, A, B, C, D):
    logLOD = np.log(C) - (1/-D)*np.log(((B - y_LOD) / (y_LOD - A)))
    return 2.71828183**logLOD

LOD = find_LOD(y_LOD, A, B, C_fit, D_fit)

# Propagate uncertainty for LOD with the formula:
# LOD_std = sqrt((∂LOD/∂C)^2 * C_fit_ci^2 + (∂LOD/∂D)^2 * D_fit_ci^2)

# Partial derivative of LOD with respect to C
dLOD_dC = ((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)
# Partial derivative of LOD with respect to D
dLOD_dD = C_fit * (((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)) * (-np.log((B - y_LOD) / (y_LOD - A)) / D_fit**2)

# Calculate LOD error using error propagation formula
LOD_error = np.sqrt((C_fit_ci * dLOD_dC)**2 + (D_fit_ci * dLOD_dD)**2)

# Plot the fitted curve
ax.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')
ax2.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')


# Mark the LOD on the plot
ax.axhline(y=y_LOD, color='black', linestyle='--')
ax.axvline(x=LOD, color='black', linestyle='--')
ax2.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=LOD, color='black', linestyle='--')


# Set x-axis limits and scales
ax.set_xlim(0.000000005, 0.00000005)
ax2.set_xlim(1, 10000)
ax.set_xscale('log')
ax2.set_xscale('log')
plt.ylim(-7.5, 75)

# Hide spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Set font size for y-axis label
ax.set_ylabel('[Reacted Reporter] (nM)', fontsize=fs)
ax2.set_ylabel('[Reacted Reporter] (nM)', fontsize=0)
ax.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax.yaxis.set_tick_params(which='both', size=3, width=1, direction='in', right='on')
ax2.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax2.yaxis.set_tick_params(which='both', size=0, width=0, direction='in', right='on')

# plt.scatter(6.29,72.68620386, color = 'red')

# Set font size for tick labels
ax.tick_params(axis='both', which='major', labelsize=fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)

# Add more ticks on the x-axis for ax2
ax2.set_xticks([10**n for n in range(1, 5)])  # Ticks at 10, 100, 1000, 10000
# ax2.get_xaxis().set_major_formatter(plt.ScalarFormatter())  # Format ticks as integers

# Add the diagonal lines for broken axis effect
d = .015  # How big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # Switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# Add a single, centered x-axis label
fig.text(0.5, 0.001, '[TNF-α] (nM)', ha='center', fontsize=fs)

plt.legend(fontsize=fs-6)

# Show plot
# plt.savefig('060624_TNFanalog_sigmoidfitting.svg')
plt.show()

# Print the fitted parameters
print(f"Fixed parameters: A = {A}, B = {B}")
print(f"Fitted parameter C: {C_fit:.2f} ± {C_fit_ci:.2f}")
print(f"Fitted parameter D: {D_fit:.2f} ± {D_fit_ci:.2f}")
print(f"LOD: {LOD:.2f} ± {LOD_error:.2f}")
# Out:
# Fixed parameters: A = 4.869470937, B = 51.10321879
# Fitted parameter C: 7.68 ± 0.96
# Fitted parameter D: 1.10 ± 0.26
# LOD: 1.62 ± 0.63
