# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.gridspec import GridSpec
from scipy.integrate import odeint
from scipy.optimize import curve_fit
import math
from scipy.stats import t

# Plot settings
lw = 2
fs = 20


# Load the data
data = pd.read_excel('Figure3b.xlsx')
data_plot = data.loc[:, 'IFN_Trial 1':'TNF_max']
protein = data['[Protein]']

# Create the subplots with gridspec
fig = plt.figure(facecolor='w')
gs = GridSpec(1, 2, width_ratios=[0.15, 0.85])  # Adjust the width ratios as needed

ax = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1], sharey=ax)

# Plot data on ax
ax.plot(protein, data_plot['Thr_Average'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0.6, 0), linewidth=1, markersize=0)
ax.plot(protein, data_plot['Thr_Trial 1'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7, label='Experiment')
ax.plot(protein, data_plot['Thr_Trial 2'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7)
ax.plot(protein, data_plot['Thr_Trial 3'], marker='o', color=(0, 0.6, 0),
        markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7)

# Plot data on ax2
ax2.plot(protein, data_plot['Thr_Average'], marker='o', color=(0, 0.6, 0),
         markerfacecolor=(0, 0.6, 0), linewidth=1, markersize=0)
ax2.plot(protein, data_plot['Thr_Trial 1'], marker='o', color=(0, 0.6, 0),
         markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7, label='Experiment')
ax2.plot(protein, data_plot['Thr_Trial 2'], marker='o', color=(0, 0.6, 0),
         markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7)
ax2.plot(protein, data_plot['Thr_Trial 3'], marker='o', color=(0, 0.6, 0),
         markerfacecolor=(0, 0.6, 0), linewidth=0, markersize=7)

ax.fill_between(protein, data_plot['Thr_min'],  data_plot['Thr_max'], color=(0,0.6,0), alpha=0.2, linewidth = 0, interpolate=True)
ax2.fill_between(protein, data_plot['Thr_min'],  data_plot['Thr_max'], color=(0,0.6,0), alpha=0.2, linewidth = 0, interpolate=True)




# Modified sigmoidal function (4PL model) with fixed A and B

L = np.array([0.000000000005, 5, 10, 100, 1000])

# A and B are determined from empirical results
A = 2.956422941 # min Reacted reporter concentration
B = 82.54095869 # max Reacted reporter concentration
def sigmoid(x, C, D):
#     C = # EC50 value
#     D = # slope of the point of inflection
    return A + (B - A) / (1 + (x / C)**D)

# Initial guesses for parameters [C, D]
initial_guesses = [1, 1]

# Perform sigmoidal regression (fit the 4PL model with fixed A and B)
popt, pcov = curve_fit(sigmoid, L, data_plot['Thr_Average'], p0=initial_guesses, bounds=(0, np.inf))
C_fit, D_fit = popt

# Generate fitted curve
L_fit = np.logspace(-8, 4, 1000)
Reporter_fit = sigmoid(L_fit, *popt)

# Standard errors of the parameters
perr = np.sqrt(np.diag(pcov))

# Confidence intervals
C_fit_ci = 1.96 * perr[0]
D_fit_ci = 1.96 * perr[1]

# Calculate LOD
y0 = 82.54095869
stdev0 = 7.676498088
y_LOD = y0 - 3 * stdev0

# Inverse function to find the corresponding concentration for y_LOD
def find_LOD(y_LOD, A, B, C, D):
    logLOD = np.log(C) - (-1/D)*np.log(((B - y_LOD) / (y_LOD - A)))
    return 2.71828183**logLOD

LOD = find_LOD(y_LOD, A, B, C_fit, D_fit)

# Partial derivative of LOD with respect to C
dLOD_dC = ((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)
# Partial derivative of LOD with respect to D
dLOD_dD = C_fit * (((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)) * (-np.log((B - y_LOD) / (y_LOD - A)) / D_fit**2)

# Calculate LOD error using error propagation formula
LOD_error = np.sqrt((C_fit_ci * dLOD_dC)**2 + (D_fit_ci * dLOD_dD)**2)

# Plot the fitted curve
ax.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')
ax2.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')


# Mark the LOD on the plot
ax.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=LOD, color='black', linestyle='--')
ax2.axhline(y=y_LOD, color='black', linestyle='--')
print("LOD:", LOD)


# Set x-axis limits and scales
ax.set_xlim(0.000000005, 0.00000005)
ax2.set_xlim(1, 10000)
ax.set_xscale('log')
ax2.set_xscale('log')
plt.ylim(-10, 110)

# Hide spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Set font size for y-axis label
ax.set_ylabel('[Reacted Reporter] (nM)', fontsize=fs)
ax2.set_ylabel('[Reacted Reporter] (nM)', fontsize=0)
ax.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax.yaxis.set_tick_params(which='both', size=3, width=1, direction='in', right='on')
ax2.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax2.yaxis.set_tick_params(which='both', size=0, width=0, direction='in', right='on')

# plt.scatter(6.29,72.68620386, color = 'red')

# Set font size for tick labels
ax.tick_params(axis='both', which='major', labelsize=fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)

# Add more ticks on the x-axis for ax2
ax2.set_xticks([10**n for n in range(1, 5)])  # Ticks at 10, 100, 1000, 10000
# ax2.get_xaxis().set_major_formatter(plt.ScalarFormatter())  # Format ticks as integers

# Add the diagonal lines for broken axis effect
d = .015  # How big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # Switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# Add a single, centered x-axis label
fig.text(0.5, 0.001, '[Thrombin] (nM)', ha='center', fontsize=fs)

plt.legend(fontsize=fs-6)

# Show plot
# plt.savefig('060624_ThrO1dART10nM_doseresp0to1000_dART_sigmoidfitting.svg')
plt.show()

# Print the fitted parameters
print(f"Fixed parameters: A = {A}, B = {B}")
print(f"Fitted parameter C: {C_fit:.2f} ± {C_fit_ci:.2f}")
print(f"Fitted parameter D: {D_fit:.2f} ± {D_fit_ci:.2f}")
print(f"LOD: {LOD:.2f} ± {LOD_error:.2f}")
# Out:
# LOD: 5.927728306380342
# Fixed parameters: A = 2.956422941, B = 82.54095869
# Fitted parameter C: 8.78 ± 0.77
# Fitted parameter D: 2.29 ± 0.59
# LOD: 5.93 ± 0.79

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.gridspec import GridSpec
from scipy.integrate import odeint
from scipy.optimize import curve_fit
import math
from scipy.stats import t

# Plot settings
lw = 2
fs = 20


# Load the data
data = pd.read_excel('Figure3b.xlsx')
data_plot = data.loc[:, 'IFN_Trial 1':'TNF_max']
protein = data['[Protein]']

# Create the subplots with gridspec
fig = plt.figure(facecolor='w')
gs = GridSpec(1, 2, width_ratios=[0.15, 0.85])  # Adjust the width ratios as needed

ax = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1], sharey=ax)

# Plot data on ax
ax.plot(protein, data_plot['IL6_Average'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0.5, 0, 0.5), linewidth=1, markersize=0)
ax.plot(protein, data_plot['IL6_Trial 1'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7, label='Experiment')
ax.plot(protein, data_plot['IL6_Trial 2'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7)
ax.plot(protein, data_plot['IL6_Trial 3'], marker='o', color=(0.5, 0, 0.5),
        markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7)

# Plot data on ax2
ax2.plot(protein, data_plot['IL6_Average'], marker='o', color=(0.5, 0, 0.5),
         markerfacecolor=(0.5, 0, 0.5), linewidth=1, markersize=0)
ax2.plot(protein, data_plot['IL6_Trial 1'], marker='o', color=(0.5, 0, 0.5),
         markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7, label='Experiment')
ax2.plot(protein, data_plot['IL6_Trial 2'], marker='o', color=(0.5, 0, 0.5),
         markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7)
ax2.plot(protein, data_plot['IL6_Trial 3'], marker='o', color=(0.5, 0, 0.5),
         markerfacecolor=(0.5, 0, 0.5), linewidth=0, markersize=7)

ax.fill_between(protein, data_plot['IL6_min'],  data_plot['IL6_max'], color=(0.5,0,0.5), alpha=0.2, linewidth = 0, interpolate=True)
ax2.fill_between(protein, data_plot['IL6_min'],  data_plot['IL6_max'], color=(0.5,0,0.5), alpha=0.2, linewidth = 0, interpolate=True)


# Modified sigmoidal function (4PL model) with fixed A and B

L = np.array([0.000000000005, 5, 10, 100, 1000])

# A and B are determined from empirical results
A = 5.971430074 # min Reacted reporter concentration
B = 92.36524155 # max Reacted reporter concentration
def sigmoid(x, C, D):
#     C = # EC50 value
#     D = # slope of the point of inflection
    return A + (B - A) / (1 + (x / C)**D)

# Initial guesses for parameters [C, D]
initial_guesses = [1, 1]

# Perform sigmoidal regression (fit the 4PL model with fixed A and B)
popt, pcov = curve_fit(sigmoid, L, data_plot['IL6_Average'], p0=initial_guesses, bounds=(0, np.inf))
C_fit, D_fit = popt

# Generate fitted curve
L_fit = np.logspace(-8, 4, 1000)
Reporter_fit = sigmoid(L_fit, *popt)

# Standard errors of the parameters
perr = np.sqrt(np.diag(pcov))

# Confidence intervals
C_fit_ci = 1.96 * perr[0]
D_fit_ci = 1.96 * perr[1]

# Calculate LOD
# y0 = 92.36524155
# stdev0 = 2.050760724
# y_LOD = y0 - 3 * stdev0
y_LOD = 86.21295937591975

# Inverse function to find the corresponding concentration for y_LOD
def find_LOD(y_LOD, A, B, C, D):
    logLOD = np.log(C) - (1/-D)*np.log(((B - y_LOD) / (y_LOD - A)))
    return 2.71828183**logLOD

LOD = find_LOD(y_LOD, A, B, C_fit, D_fit)

# Partial derivative of LOD with respect to C
dLOD_dC = ((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)
# Partial derivative of LOD with respect to D
dLOD_dD = C_fit * (((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)) * (-np.log((B - y_LOD) / (y_LOD - A)) / D_fit**2)

# Calculate LOD error using error propagation formula
LOD_error = np.sqrt((C_fit_ci * dLOD_dC)**2 + (D_fit_ci * dLOD_dD)**2)

# Plot the fitted curve
ax.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')
ax2.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')


# Mark the LOD on the plot
ax.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=3, color='black', linestyle='--')
ax2.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=3, color='black', linestyle='--')


# Set x-axis limits and scales
ax.set_xlim(0.000000005, 0.00000005)
ax2.set_xlim(1, 10000)
ax.set_xscale('log')
ax2.set_xscale('log')
plt.ylim(-10, 110)

# Hide spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Set font size for y-axis label
ax.set_ylabel('[Reacted Reporter] (nM)', fontsize=fs)
ax2.set_ylabel('[Reacted Reporter] (nM)', fontsize=0)
ax.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax.yaxis.set_tick_params(which='both', size=3, width=1, direction='in', right='on')
ax2.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax2.yaxis.set_tick_params(which='both', size=0, width=0, direction='in', right='on')

# plt.scatter(6.29,72.68620386, color = 'red')

# Set font size for tick labels
ax.tick_params(axis='both', which='major', labelsize=fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)

# Add more ticks on the x-axis for ax2
ax2.set_xticks([10**n for n in range(1, 5)])  # Ticks at 10, 100, 1000, 10000
# ax2.get_xaxis().set_major_formatter(plt.ScalarFormatter())  # Format ticks as integers

# Add the diagonal lines for broken axis effect
d = .015  # How big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # Switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# Add a single, centered x-axis label
fig.text(0.5, 0.001, '[IL-6] (nM)', ha='center', fontsize=fs)

plt.legend(fontsize=fs-6)

# Show plot
# plt.savefig('060624_IL6O1dART10nM_doseresp0to1000_dART_sigmoidfitting.svg')
plt.show()

# Print the fitted parameters
print(f"Fixed parameters: A = {A}, B = {B}")
print(f"Fitted parameter C: {C_fit:.2f} ± {C_fit_ci:.2f}")
print(f"Fitted parameter D: {D_fit:.2f} ± {D_fit_ci:.2f}")
print(f"LOD: {LOD:.2f} ± {LOD_error:.2f}")
# Out:
# Fixed parameters: A = 5.971430074, B = 92.36524155
# Fitted parameter C: 29.36 ± 5.85
# Fitted parameter D: 1.02 ± 0.15
# LOD: 2.38 ± 1.02

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.gridspec import GridSpec
from scipy.integrate import odeint
from scipy.optimize import curve_fit
import math
from scipy.stats import t

# Plot settings
lw = 2
fs = 20


# Load the data
data = pd.read_excel('Figure3b.xlsx')
data_plot = data.loc[:, 'IFN_Trial 1':'TNF_max']
protein = data['[Protein]']

# Create the subplots with gridspec
fig = plt.figure(facecolor='w')
gs = GridSpec(1, 2, width_ratios=[0.15, 0.85])  # Adjust the width ratios as needed

ax = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1], sharey=ax)

# Plot data on ax
ax.plot(protein, data_plot['TNF_Average'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=1, markersize=0)
ax.plot(protein, data_plot['TNF_Trial 1'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7, label='Experiment')
ax.plot(protein, data_plot['TNF_Trial 2'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7)
ax.plot(protein, data_plot['TNF_Trial 3'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7)

# Plot data on ax2
ax2.plot(protein, data_plot['TNF_Average'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=1, markersize=0)
ax2.plot(protein, data_plot['TNF_Trial 1'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7, label='Experiment')
ax2.plot(protein, data_plot['TNF_Trial 2'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7)
ax2.plot(protein, data_plot['TNF_Trial 3'], marker='o', color=(1, 0, 0),
        markerfacecolor=(1, 0, 0), linewidth=0, markersize=7)

ax.fill_between(protein, data_plot['TNF_min'],  data_plot['TNF_max'], color=(1,0,0), alpha=0.2, linewidth = 0, interpolate=True)
ax2.fill_between(protein, data_plot['TNF_min'],  data_plot['TNF_max'], color=(1,0,0), alpha=0.2, linewidth = 0, interpolate=True)


# Modified sigmoidal function (4PL model) with fixed A and B

L = np.array([0.000000000005, 5, 10, 100, 1000])

# A and B are determined from empirical results
A = 13.98653387 # min Reacted reporter concentration
B = 71.34039519 # max Reacted reporter concentration
def sigmoid(x, C, D):
#     C = # EC50 value
#     D = # slope of the point of inflection
    return A + (B - A) / (1 + (x / C)**D)

# Initial guesses for parameters [C, D]
initial_guesses = [1, 1]

# Perform sigmoidal regression (fit the 4PL model with fixed A and B)
popt, pcov = curve_fit(sigmoid, L, data_plot['TNF_Average'], p0=initial_guesses, bounds=(0, np.inf))
C_fit, D_fit = popt

# Generate fitted curve
L_fit = np.logspace(-8, 4, 1000)
Reporter_fit = sigmoid(L_fit, *popt)

# Confidence intervals
C_fit_ci = 1.96 * perr[0]
D_fit_ci = 1.96 * perr[1]

# # Calculate LOD
y0 = 71.34039519
stdev0 =6.612390425
y_LOD = y0 - 3 * stdev0
# y_LOD = 51.503223914984105

# Inverse function to find the corresponding concentration for y_LOD
def find_LOD(y_LOD, A, B, C, D):
    logLOD = np.log(C) - (1/-D)*np.log(((B - y_LOD) / (y_LOD - A)))
    return 2.71828183**logLOD

LOD = find_LOD(y_LOD, A, B, C_fit, D_fit)

# Partial derivative of LOD with respect to C
dLOD_dC = ((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)
# Partial derivative of LOD with respect to D
dLOD_dD = C_fit * (((B - y_LOD) / (y_LOD - A)) ** (1 / D_fit)) * (-np.log((B - y_LOD) / (y_LOD - A)) / D_fit**2)

# Calculate LOD error using error propagation formula
LOD_error = np.sqrt((C_fit_ci * dLOD_dC)**2 + (D_fit_ci * dLOD_dD)**2)

# Plot the fitted curve
ax.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')
ax2.plot(L_fit, Reporter_fit, '--', linewidth=2, color='orange', label='Fitted Sigmoidal Curve')


# Mark the LOD on the plot
ax.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=LOD, color='black', linestyle='--')
ax2.axhline(y=y_LOD, color='black', linestyle='--')
ax2.axvline(x=LOD, color='black', linestyle='--')


# Set x-axis limits and scales
ax.set_xlim(0.000000005, 0.00000005)
ax2.set_xlim(1, 10000)
ax.set_xscale('log')
ax2.set_xscale('log')
plt.ylim(-10, 110)

# Hide spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Set font size for y-axis label
ax.set_ylabel('[Reacted Reporter] (nM)', fontsize=fs)
ax2.set_ylabel('[Reacted Reporter] (nM)', fontsize=0)
ax.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax.yaxis.set_tick_params(which='both', size=3, width=1, direction='in', right='on')
ax2.xaxis.set_tick_params(which='both', size=3, width=1, direction='in', top='on')
ax2.yaxis.set_tick_params(which='both', size=0, width=0, direction='in', right='on')

# plt.scatter(6.29,72.68620386, color = 'red')

# Set font size for tick labels
ax.tick_params(axis='both', which='major', labelsize=fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)

# Add more ticks on the x-axis for ax2
ax2.set_xticks([10**n for n in range(1, 5)])  # Ticks at 10, 100, 1000, 10000
# ax2.get_xaxis().set_major_formatter(plt.ScalarFormatter())  # Format ticks as integers

# Add the diagonal lines for broken axis effect
d = .015  # How big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # Switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# Add a single, centered x-axis label
fig.text(0.5, 0.001, '[TNF-α] (nM)', ha='center', fontsize=fs)

plt.legend(fontsize=fs-6)

# Show plot
# plt.savefig('060624_TNFO1dART10nM_doseresp0to1000_dART_sigmoidfitting.svg')
plt.show()

# Print the fitted parameters
print(f"Fixed parameters: A = {A}, B = {B}")
print(f"Fitted parameter C: {C_fit:.2f} ± {C_fit_ci:.2f}")
print(f"Fitted parameter D: {D_fit:.2f} ± {D_fit_ci:.2f}")
print(f"LOD: {LOD:.2f} ± {LOD_error:.2f}")
# Out:
# Fixed parameters: A = 13.98653387, B = 71.34039519
# Fitted parameter C: 18.28 ± 5.85
# Fitted parameter D: 0.86 ± 0.15
# LOD: 8.69 ± 3.01
